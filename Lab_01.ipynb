# %% [markdown]
# # **Laboratório 01 - Expansão em Séries de Taylor**
#
# Aluno:
#
# **Exemplo 01** - Expansão da função $f(x) = e^x$, via Série de MacLaurin
#
# $$
# f(x) = e^x \approx \sum_{k=0}^{N}\frac{x^k}{k!}
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt
import math


def mac(x, N):
    soma = 0
    for k in range(N+1):
        soma += (x**k) / math.factorial(k)
    return soma


x = np.linspace(0,2*np.pi,100)
result = mac(x, 10)
print(f"Resultado {result}")
plt.plot(result)
plt.show()
# Out:
# Resultado [  1.           1.06552381   1.13534099   1.20973286   1.28899916
#    1.3734593    1.46345358   1.55934464   1.66151884   1.77038788
#    1.88639044   2.00999393   2.14169639   2.28202849   2.43155569
#    2.59088047   2.76064481   2.94153275   3.13427313   3.33964255
#    3.5584685    3.79163266   4.04007447   4.3047949    4.58686048
#    4.88740755   5.20764688   5.54886846   5.91244671   6.29984596
#    6.71262629   7.15244976   7.62108707   8.1204245    8.65247151
#    9.21936859   9.82339579  10.46698164  11.15271273  11.88334381
#   12.66180854  13.49123093  14.37493741  15.31646966  16.31959826
#   17.38833707  18.52695858  19.74001002  21.03233058  22.40906951
#   23.87570537  25.43806631  27.10235156  28.87515419  30.76348504
#   32.77479811  34.91701734  37.19856484  39.62839073  42.21600458
#   44.97150859  47.90563254  51.02977063  54.35602024  57.89722286
#   61.667007    65.67983349  69.95104301  74.49690618  79.33467605
#   84.48264344  89.96019487  95.78787352 101.98744316 108.5819552
#  115.59581905 123.05487591 130.986476   139.41955964 148.38474199
#  157.91440198 168.04277518 178.80605115 190.24247517 202.39245464
#  215.29867031 229.00619254 243.5626027  259.01812    275.42573387
#  292.84134221 311.3238955  330.93554723 351.74181079 373.81172287
#  397.21801393 422.03728571 448.35019613 476.24165185 505.80100871]

# %% [markdown]
# **Exemplo 02** - Implementar a função
#
# \begin{equation}
#      f(x) = sen(x) \approx \sum_{k=0}^{N} (-1)^k \frac{x^{2k+1}}{(2k+1)!}
# \end{equation}

# %%
def sen(x, N):
    soma = 0
    for k in range(N+1):
        soma += ((-1)**k) * ((x**((2*k)+1)) / math.factorial((2*k) + 1))

    return soma

x= np.linspace(0,2*np.pi,100)
result = sen(x, 10)
plt.plot(result)
plt.show()

# %% [markdown]
# **Exemplo 03** : Use a expansão em Série de MacLaurin para mostrar que
#
# \begin{equation}
# e^{ix} = cos\,x + i\,sen\,x,\,\,\,\,\,\,i = \sqrt{-1}.
# \end{equation}

# %%
x= np.linspace(0,2*np.pi,100)

result = mac(x, 20)
result = result**1j
result2 = np.cos(x) + 1j*np.sin(x)
print(f"Resultado1 {result}")
print(f"Resultado2 {result2}")
plt.plot(result)
plt.plot(result2)

plt.show()
# Out:
# Resultado1 [ 1.        +0.00000000e+00j  0.99798668+6.34239197e-02j
#   0.99195481+1.26592454e-01j  0.9819287 +1.89251244e-01j
#  -0.5       -8.66025404e-01j -0.44406661-8.95993774e-01j
#  -0.38634513-9.22354294e-01j -0.32706796-9.45000819e-01j
#  -0.26647381-9.63842159e-01j -0.20480667-9.78802446e-01j
#  -0.14231484-9.89821442e-01j -0.07924996-9.96854776e-01j
#  -0.01586596-9.99874128e-01j  0.04758192-9.98867339e-01j
#   0.1108382 -9.93838464e-01j  0.17364818-9.84807753e-01j
#   0.23575894-9.71811568e-01j  0.29692038-9.54902241e-01j
#   0.35688622-9.34147860e-01j  0.41541501-9.09631995e-01j
#   0.47227107-8.81453363e-01j  0.52722547-8.49725430e-01j
#   0.58005691-8.14575952e-01j  0.63055267-7.76146464e-01j
#   0.67850941-7.34591709e-01j  0.72373404-6.90079011e-01j
#   0.76604444-6.42787610e-01j  0.80527026-5.92907929e-01j
#   0.84125353-5.40640817e-01j  0.87384938-4.86196736e-01j
#   0.90292654-4.29794912e-01j  0.92836793-3.71662456e-01j
#   0.95007112-3.12033446e-01j  0.9679487 -2.51147987e-01j
#   0.9819287 -1.89251244e-01j  0.99195481-1.26592454e-01j
#   0.99798668-6.34239197e-02j  1.        -2.44929360e-16j]

# %% [markdown]
# # **Exercícios**
#
# **01** - O valor de $\pi$ pode ser aproximado por meio da seguinte expansão em série:
#
# \begin{equation}
# \pi \approx 4 \sum_{i=1}^{n} (-1)^{i-1} \frac{1}{2i - 1}
# \end{equation}
#
# escreva uma função que retorne o valor aproximado de $\pi$ que receba como parâmetro de entrada os $n$ termos da série. Calcule o erro relativo para diferentes valores de $n$. Por exemplo: $n = 5,\,10,\,20,\,30.$

# %%
def relative_error(a,b):
    return np.abs(a - b) / np.abs(a)

def pi(n):
    soma = 0
    error = None
    for i in range(1,n+1):
        soma += ((-1) ** (i-1)) * (1 / (2*i-1))
        if i % 5 == 0:
            error = relative_error(np.pi,soma)

    return 4*soma,error

n= 50
print(f"n ",end="")
print(f"Pi ",end="")
print(f"Erro ")

for i in range(5,n+5,5):
    print(f"{i} ",end="")
    p,erro = pi(i)
    print(f"{p} ",end="")
    print(f"{erro} ")
# Out:
# n Pi Erro
# 5 3.3396825396825403 0.7342365077259144
# 10 3.0418396189294032 0.7579380942773091
# 15 3.208185652261944 0.7447006975430076
# 20 3.09162380666784 0.7539763944941155
# 25 3.1815766854350325 0.7468181718435432
# 30 3.108268566698947 0.7526518465763511
# 35 3.1701582571925884 0.7477268214921058
# 40 3.116596556793833 0.7519891261815402
# 45 3.163812134018756 0.7482318299283985
# 50 3.121594652591011 0.7515913903554564

# %% [markdown]
# **02** - Use a expansão em série de Taylor para mostrar que
# \begin{equation}
#     \frac{sen\,x}{x} \approx 1
# \end{equation}
# com um valor bem pequeno em $x.$

# %%
def sen(x, N):
    soma = 0
    for k in range(N+1):
        soma += ((-1)**k) * ((x**((2*k)+1)) / math.factorial((2*k) + 1))

    return soma


x= np.pi / 4
seno = sen(x,20)
print(f"Valor Seno: {seno}")
print(f"Seno sobre x: {seno/x}")
# Out:
# Valor Seno: 0.7071067811865475
# Seno sobre x: 0.9003163161571061

# %% [markdown]
# **03** - Escreva a expansão em série de Taylor para $f(x) = e^{x^2}$ em torno da origem. Defina uma função $exp$\_$dupla(x,n),$ para calcular uma aproximação para $f(x)$ utilizando os $n$ primeiros termos da expansão. Adapte a função para receber como parâmetro de entrada um vetor.

# %%
result213 = mac(2,50)
print(result213**2)
# Out:
# 54.598150033144215

# %% [markdown]
# **04** - Sabendo que o seno hiperbólico pode ser obtido por meio da seguinte expansão,
# \begin{equation}
#     senh\,x = \sum_{k=0}^{\infty} \frac{x^{2k+1}}{(2k+1)!}
# \end{equation}
# o cosseno hiperbólico por,
# \begin{equation}
#     cosh\,x = \sum_{k=0}^{\infty} \frac{x^{2k}}{(2k)!}
# \end{equation}
# e a tangente hiperbólica é dada por,
# \begin{equation}
#     tanh\,x = \frac{senh\,x}{cosh\,x}
# \end{equation}
# calcule a tangente hiperbólica de $x_0 = 0,5$ a partir das funções $ senh\,x$ e $ cosh\,x$, com um erro relatico de aproximadamente $10^{-5}.$ Gerar os gráficos e comparar com a função $np.tanh(x)$.

# %%
def senh(x, N):
    soma = 0.0
    for k in range(N+1):
        soma += ((x**((2*k) + 1)) / math.factorial((2*k) + 1))
    return soma



def cosh(x, N):
    soma = 0.0
    for k in range(N+1):
        soma += ((x**(2*k)) / math.factorial(2*k))
    return soma



def tanh(x,error_target):
    count = 1
    tanh_value = senh(x,count) / cosh(x,count)
    error = relative_error((tanh_value),(np.sinh(x) / np.cosh(x)))

    while error > error_target:
        count += 1
        tanh_value =  senh(x,count)/ cosh(x,count)
        error = relative_error((tanh_value),(np.sinh(x) / np.cosh(x)))
        pass

    return tanh_value

# print(f"1 {senh(1,100)/cosh(1,100)}")
# print(f"2 {np.tanh(1)}")


x= np.linspace(0,2*np.pi,100)
res = tanh(x,1e-5)
print(f"minha {res}")
print(f"sua {np.tanh(x)}")
# Out:
# /tmp/ipykernel_3597/444460191.py:2: RuntimeWarning: invalid value encountered in divide
#   return np.abs(a - b) / np.abs(a)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 35
#      30 # print(f"1 {senh(1,100)/cosh(1,100)}")
#      31 # print(f"2 {np.tanh(1)}")
#      34 x= np.linspace(0,2*np.pi,100)
# ---> 35 res = tanh(x,1e-5)
#      36 print(f"minha {res}")
#      37 print(f"sua {np.tanh(x)}")
#
# Cell In[31], line 22, in tanh(x, error_target)
#      19 tanh_value = senh(x,count) / cosh(x,count)
#      20 error = relative_error((tanh_value),(np.sinh(x) / np.cosh(x)))
# ---> 22 while error > error_target:
#      23     count += 1
#      24     tanh_value =  senh(x,count)/ cosh(x,count)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
