# %% [markdown]
# # **Laboratório 01 - Expansão em Séries de Taylor**
#
# Aluno:
#
# **Exemplo 01** - Expansão da função $f(x) = e^x$, via Série de MacLaurin
#
# $$
# f(x) = e^x \approx \sum_{k=0}^{N}\frac{x^k}{k!}
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt
import math


def mac(x, N):
    soma = 0
    for k in range(N+1):
        soma += (x**k) / math.factorial(k)
    return soma


teste = np.linspace()
result = mac(1, 10)
print(f"Resultado {result}")
plt.plot(result)
plt.show()
# Out:
# Resultado 2.7182818011463845

# %% [markdown]
# **Exemplo 02** - Implementar a função
#
# \begin{equation}
#      f(x) = sen(x) \approx \sum_{k=0}^{N} (-1)^k \frac{x^{2k+1}}{(2k+1)!}
# \end{equation}

# %%
def func(x, N):
    soma = 0
    for k in range(N+1):
        soma += ((-1)**k) * ((x**((2*k)+1)) / math.factorial((2*k) + 1))

    return soma

x= np.linspace(0,2*np.pi,100)
result = func(x, 10)
plt.plot(result)
plt.show()
# Out:
# Resultado [ 0.00000000e+00  6.34239197e-02  1.26592454e-01  1.89251244e-01
#   2.51147987e-01  3.12033446e-01  3.71662456e-01  4.29794912e-01
#   4.86196736e-01  5.40640817e-01  5.92907929e-01  6.42787610e-01
#   6.90079011e-01  7.34591709e-01  7.76146464e-01  8.14575952e-01
#   8.49725430e-01  8.81453363e-01  9.09631995e-01  9.34147860e-01
#   9.54902241e-01  9.71811568e-01  9.84807753e-01  9.93838464e-01
#   9.98867339e-01  9.99874128e-01  9.96854776e-01  9.89821442e-01
#   9.78802446e-01  9.63842159e-01  9.45000819e-01  9.22354294e-01
#   8.95993774e-01  8.66025404e-01  8.32569855e-01  7.95761841e-01
#   7.55749574e-01  7.12694171e-01  6.66769001e-01  6.18158986e-01
#   5.67059864e-01  5.13677392e-01  4.58226522e-01  4.00930535e-01
#   3.42020143e-01  2.81732557e-01  2.20310533e-01  1.58001396e-01
#   9.50560433e-02  3.17279335e-02 -3.17279335e-02 -9.50560433e-02
#  -1.58001396e-01 -2.20310533e-01 -2.81732557e-01 -3.42020143e-01
#  -4.00930535e-01 -4.58226521e-01 -5.13677391e-01 -5.67059863e-01
#  -6.18158985e-01 -6.66768999e-01 -7.12694170e-01 -7.55749572e-01
#  -7.95761837e-01 -8.32569849e-01 -8.66025396e-01 -8.95993764e-01
#  -9.22354279e-01 -9.45000798e-01 -9.63842129e-01 -9.78802405e-01
#  -9.89821386e-01 -9.96854699e-01 -9.99874022e-01 -9.98867196e-01
#  -9.93838270e-01 -9.84807491e-01 -9.71811216e-01 -9.54901770e-01
#  -9.34147231e-01 -9.09631159e-01 -8.81452256e-01 -8.49723968e-01
#  -8.14574028e-01 -7.76143941e-01 -7.34588410e-01 -6.90074713e-01
#  -6.42782025e-01 -5.92900696e-01 -5.40631475e-01 -4.86184705e-01
#  -4.29779461e-01 -3.71642666e-01 -3.12008168e-01 -2.51115783e-01
#  -1.89210320e-01 -1.26540579e-01 -6.33583264e-02  8.27409522e-05]

# %% [markdown]
# **Exemplo 03** : Use a expansão em Série de MacLaurin para mostrar que
#
# \begin{equation}
# e^{ix} = cos\,x + i\,sen\,x,\,\,\,\,\,\,i = \sqrt{-1}.
# \end{equation}

# %%
result = mac(1j, 20)
result2 = np.cos(1) + 1j*np.sin(1)
print(f"Resultado1 {result[-1]}")
print(f"Resultado2 {result2}")
plt.plot(result)
plt.show()
# Out:
# Resultado1 (0.5403023058681397+0.8414709848078965j)
# Resultado2 (0.5403023058681398+0.8414709848078965j)
# /home/pedro/code/lab-CN/.venv/lib/python3.13/site-packages/matplotlib/cbook.py:1719: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /home/pedro/code/lab-CN/.venv/lib/python3.13/site-packages/matplotlib/cbook.py:1355: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %% [markdown]
# # **Exercícios**
#
# **01** - O valor de $\pi$ pode ser aproximado por meio da seguinte expansão em série:
#
# \begin{equation}
# \pi \approx 4 \sum_{i=1}^{n} (-1)^{i-1} \frac{1}{2i - 1}
# \end{equation}
#
# escreva uma função que retorne o valor aproximado de $\pi$ que receba como parâmetro de entrada os $n$ termos da série. Calcule o erro relativo para diferentes valores de $n$. Por exemplo: $n = 5,\,10,\,20,\,30.$

# %%
def relative_error(a,b):
    return np.abs(a - b) / np.abs(a)

def pi(n):
    soma = 0
    error = None
    for i in range(1,n+1):
        soma += ((-1) ** (i-1)) * (1 / (2*i-1))
        if i % 5 == 0:
            error = relative_error(np.pi,soma)
            pass
            

    return 4*soma,error


print(f"n ",end="")
print(f"Pi ",end="")
print(f"Erro ")

    

for i in range(5,50+5,5):
    print(f"{i} ",end="")
    p,erro = pi(i)
    print(f"{p} ",end="")
    print(f"{erro} ")
# Out:
# n Pi Erro
# 5 3.3396825396825403 0.7342365077259144
# 10 3.0418396189294032 0.7579380942773091
# 15 3.208185652261944 0.7447006975430076
# 20 3.09162380666784 0.7539763944941155
# 25 3.1815766854350325 0.7468181718435432
# 30 3.108268566698947 0.7526518465763511
# 35 3.1701582571925884 0.7477268214921058
# 40 3.116596556793833 0.7519891261815402
# 45 3.163812134018756 0.7482318299283985
# 50 3.121594652591011 0.7515913903554564

# %% [markdown]
# **02** - Use a expansão em série de Taylor para mostrar que
# \begin{equation}
#     \frac{sen\,x}{x} \approx 1
# \end{equation}
# com um valor bem pequeno em $x.$

# %%
def sen(x, N):
    soma = 0

    for n in range(N+1):
        soma += ((-1) ** n ) * ( ( x ** (( 2 * n ) + 1)) / ( math.factorial(2*n + 1) ) )

    return soma

x = 2
seno = sen(x,20)
print(f"{seno}")
print(f"{np.sin(x)}")
# Out:
# 0.9092974268256817
# 0.9092974268256817

# %% [markdown]
# **03** - Escreva a expansão em série de Taylor para $f(x) = e^{x^2}$ em torno da origem. Defina uma função $exp$\_$dupla(x,n),$ para calcular uma aproximação para $f(x)$ utilizando os $n$ primeiros termos da expansão. Adapte a função para receber como parâmetro de entrada um vetor.

# %%
result213 = mac(2,50)
print(result213[-1]**2)
# Out:
# 54.598150033144215

# %% [markdown]
# **04** - Sabendo que o seno hiperbólico pode ser obtido por meio da seguinte expansão,
# \begin{equation}
#     senh\,x = \sum_{k=0}^{\infty} \frac{x^{2k+1}}{(2k+1)!}
# \end{equation}
# o cosseno hiperbólico por,
# \begin{equation}
#     cosh\,x = \sum_{k=0}^{\infty} \frac{x^{2k}}{(2k)!}
# \end{equation}
# e a tangente hiperbólica é dada por,
# \begin{equation}
#     tanh\,x = \frac{senh\,x}{cosh\,x}
# \end{equation}
# calcule a tangente hiperbólica de $x_0 = 0,5$ a partir das funções $ senh\,x$ e $ cosh\,x$, com um erro relatico de aproximadamente $10^{-5}.$ Gerar os gráficos e comparar com a função $np.tanh(x)$.

# %%
def senh(x, N):
    soma = 0.0
    for k in range(N+1):
        soma += ((x**((2*k) + 1)) / math.factorial((2*k) + 1))
    return soma



def cosh(x, N):
    soma = 0.0
    for k in range(N+1):
        soma += ((x**(2*k)) / math.factorial(2*k))
    return soma



def tanh(x,error_target):
    valores:list[float] = []
    count = 1
    tanh_value = senh(x,count) / cosh(x,count)
    error = relative_error((tanh_value),(senh(x,count-1) / cosh(x,count-1)))

    while error > error_target:
        count += 1
        tanh_value =  senh(x,count)/ cosh(x,count)
        error = relative_error((tanh_value),(senh(x,count-1) / cosh(x,count-1)))
        valores.append(tanh_value)
        pass

    return tanh_value

# print(f"1 {senh(1,100)/cosh(1,100)}")
# print(f"2 {np.tanh(1)}")


x = 1
res = tanh(x,1e-5)
print(f"minha {res}")
print(f"sua {np.tanh(x)}")
# Out:
# minha 0.7615941568872626
# sua 0.7615941559557649
